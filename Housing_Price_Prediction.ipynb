# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading dataset
hp=pd.read_csv('HousePrices.csv')

# %% [markdown]
# ## Performing EDA

# %%
hp.shape
# Out:
# (1460, 81)

# %%
hp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
hp.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Checking for total null values
hp.isnull().sum()[hp.isnull().sum()>0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
hp.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage'], axis = 1, inplace = True)

# %%
hp.dropna(inplace=True)

# %%
hp.shape
# Out:
# (1338, 75)

# %%
hp.corr()
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.016725 -0.036083    -0.044455     0.011850
# MSSubClass     0.016725    1.000000 -0.134158     0.051690    -0.098153
# LotArea       -0.036083   -0.134158  1.000000     0.090451     0.001415
# OverallQual   -0.044455    0.051690  0.090451     1.000000    -0.163080
# OverallCond    0.011850   -0.098153  0.001415    -0.163080     1.000000
# YearBuilt     -0.023595    0.056456 -0.005022     0.570668    -0.417330
# YearRemodAdd  -0.028434    0.038513  0.001681     0.549460     0.035076
# MasVnrArea    -0.051038    0.031333  0.096727     0.401175    -0.141080
# BsmtFinSF1    -0.004919   -0.069053  0.210148     0.197441    -0.060068
# BsmtFinSF2    -0.004908   -0.079329  0.110493    -0.086014     0.035698
# BsmtUnfSF     -0.010196   -0.141025 -0.014589     0.292940    -0.161038
# TotalBsmtSF   -0.018637   -0.263613  0.267188     0.505897    -0.228020
# ...

# %%
#Checking for total null values
hp.isnull().sum()[hp.isnull().sum()>0].sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
# Removed ID column as it was not important for training algorithm.
hp.drop(['Id'],axis=1, inplace=True)

# MSSubClass is actually a categorical variable, hence converting it to the categorical one
hp['MSSubClass'] = hp['MSSubClass'].astype('object')

# %%
# Finding How many Numeric and Categorical features
numeric_features = hp.select_dtypes(exclude=['object'])#.copy()
categorical_features = hp.select_dtypes(include=['object'])#.copy()

print("Number of numerical features are: ", numeric_features.shape[1])
print("Number of categorical features are: ", categorical_features.shape[1])
# Out:
# Number of numerical features are:  35
# Number of categorical features are:  39

# %%
# Printing Numeric and Categorical features
numeric_features.columns, categorical_features.columns
# Out:
# (Index(['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#         'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#         '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#         'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#         'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea',
#         'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#         'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#        dtype='object'),
#  Index(['MSSubClass', 'MSZoning', 'Street', 'LotShape', 'LandContour',
#         'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#         'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#         'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
#         'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
# ...

# %%
#checking for outliers on Numeric features
plt.figure(figsize = (25,100))
count = 1
for col in numeric_features:
    plt.subplot(20,4,count)
    plt.boxplot(numeric_features[col])
    plt.title(col)
    count +=1
        
plt.show()

# %%
# converting categorical data into Numerical data
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for col in categorical_features.columns:
    hp[col]=labelencoder.fit_transform(hp[col])
hp.head()
# Out:
#    MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0           5         3     8450       1         3            3          0
# 1           0         3     9600       1         3            3          0
# 2           5         3    11250       1         0            3          0
# 3           6         3     9550       1         0            3          0
# 4           5         3    14260       1         0            3          0
#
#    LotConfig  LandSlope  Neighborhood  ...  EnclosedPorch  3SsnPorch  \
# 0          4          0             5  ...              0          0
# 1          2          0            24  ...              0          0
# 2          4          0             5  ...              0          0
# 3          0          0             6  ...            272          0
# 4          2          0            15  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
hp.tail()
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 1455           5         3     7917       1         3            3          0
# 1456           0         3    13175       1         3            3          0
# 1457           6         3     9042       1         3            3          0
# 1458           0         3     9717       1         3            3          0
# 1459           0         3     9937       1         3            3          0
#
#       LotConfig  LandSlope  Neighborhood  ...  EnclosedPorch  3SsnPorch  \
# 1455          4          0             8  ...              0          0
# 1456          4          0            14  ...              0          0
# 1457          4          0             6  ...              0          0
# 1458          4          0            12  ...            112          0
# 1459          4          0             7  ...              0          0
#
# ...

# %%
#seperating X and y
X = hp.iloc[:,:-1].values
y = hp.iloc[:,-1].values

# %%
#dividing into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
MLR = LinearRegression()
MLR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction
y_pred = MLR.predict(X_test)
print(MLR.coef_)
print(MLR.intercept_)
# Out:
# [-1.80669539e+03 -2.85518440e+02  3.36869221e-03  5.95006512e+03
#  -1.18569992e+03  7.31892689e+03 -7.15709803e-09 -1.42800261e+02
#   1.09689920e+04  4.44296490e+02 -1.25885584e+03 -9.83078805e+03
#  -1.13382430e+03 -1.39553093e+03  1.34023693e+04  3.81398573e+03
#   1.62680432e+02  6.36791178e+01  2.61770033e+03  5.47656270e+03
#  -5.98762917e+02 -5.50546191e+02  2.33855810e+03  2.39362346e+01
#  -6.91091705e+03 -1.83147029e+03  1.52416488e+03 -1.04851169e+04
#   3.51611565e+03 -4.92766001e+03 -1.34275465e+03 -2.95111374e+00
#   7.86706792e+02  9.42440613e+00 -3.64378187e+00  2.82951049e+00
#  -6.78524488e+03 -7.42553664e+02  3.11973035e+03 -6.51459947e+02
#   1.00451889e+01  1.65668913e+01  9.44212778e+00  3.60542081e+01
#   8.06433630e+03  1.00303919e+03  5.66545787e+03 -2.92756574e+03
#  -4.00395038e+03 -1.78599951e+04 -8.39770012e+03  2.22513684e+03
#   5.26636495e+03  6.68479665e+03  8.48962182e+02 -1.02412231e+02
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.8208981432169107

# %%
prediction_output =pd.DataFrame(data=[y_test,y_pred],index=['y_test','y_pred'])
prediction_output.transpose()
# Out:
#        y_test         y_pred
# 0    239686.0  269449.747826
# 1    222500.0  227111.160268
# 2    159500.0  132596.522119
# 3    109500.0  107646.383831
# 4    235000.0  232669.471703
# ..        ...            ...
# 397  145000.0   79147.006609
# 398  162000.0  170441.779451
# 399  217000.0  228735.489296
# 400  230000.0  212841.807419
# 401  176000.0  176052.745374
#
# [402 rows x 2 columns]
